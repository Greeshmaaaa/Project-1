# %%
import pandas as pd
import datetime as dt
import numpy as np
import numpy as np
import netCDF4 as nc
import xarray as xr

import pandas as pd
import metpy
import metpy.calc as mpcalc
from metpy.cbook import get_test_data
from metpy.units import units
import matplotlib.pyplot as plt

# %%
test = xr.open_dataset("/g/data/up6/gs5098/Radar/filtered_reflectivity_with_metadata.nc")
print(test.corrected_reflectivity)
# Out:
# <xarray.DataArray 'corrected_reflectivity' (time: 3960, range: 596)> Size: 9MB
# [2360160 values with dtype=float32]
# Coordinates:
#   * time       (time) datetime64[ns] 32kB 2001-12-03T02:40:00 ... 2001-12-03T...
#   * range      (range) float32 2kB 1.125e+03 1.375e+03 ... 1.496e+05 1.499e+05
#     azimuth    (time) float32 16kB ...
#     elevation  (time) float64 32kB ...
# Attributes:
#     calibration_offset:       -3.7
#     calibration_units:        dBZ
#     calibration_description:  Technique implemented using satellite matching ...
#     calibration_comment:      GR_cal = GR - cal_offset
#     comment:                  Radar reflectivity has not been corrected for w...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
reflectivity = np.array([
    np.nan, 43.3125, 53.0625, 53.125, 54.6875, 55.0625, 55.4375, 55.5, 54.875,
    55.25, 51.9375, 48.125, 45.0625, 42.125, 39.1875, 36.3125, 33.1875, 28.625,
    23.5625, 21., 17.875, 14.8125, 12.125, 9.4375, 8.1875, 7.0625, 6.3125,
    5.5625, 5.3125, 4.875, 4.6875, 4.9375, np.nan, np.nan, np.nan, np.nan,
    np.nan, np.nan, np.nan, np.nan, np.nan
])
z_levels = np.array([
    0., 500., 1000., 1500., 2000., 2500., 3000., 3500., 4000., 4500.,
    5000., 5500., 6000., 6500., 7000., 7500., 8000., 8500., 9000., 9500.,
    10000., 10500., 11000., 11500., 12000., 12500., 13000., 13500., 14000., 
    14500., 15000., 15500., 16000., 16500., 17000., 17500., 18000., 18500., 
    19000., 19500., 20000.
]) / 1000  # Convert meters to kilometers

# Plot
plt.figure(figsize=(8, 6))
plt.plot(reflectivity, z_levels, label="Maximum Reflectivity")
plt.axvline(x=50, color='red', linestyle='--', label="Reflectivity = 50 dBz")

# Set axis limits and ticks
plt.xlim(0, 65)
plt.ylim(0, 20)
plt.xticks(np.arange(0, 72, 10), fontsize=26)
plt.yticks(np.arange(0, 23, 3), fontsize=26)

# Customize font sizes
plt.title("Badgerys Creek\nMaximum Reflectivity at Each Z-Level", fontsize=24)
plt.xlabel("Reflectivity (dBz)", fontsize=26)
plt.ylabel("Height (km)", fontsize=26)
plt.legend(fontsize=20, loc = 'upper right')

# Add grid and layout adjustments
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
reflectivity = np.array([
   np.nan, 60.9375, 62.125, 64.25, 65.8125, 65.75, 65.125, 64.375, 
 63.875, 63.625, 63.625, 64.125, 63.6875, 63.1875, 62.8125, 62.5, 
 61.75, 61.0, 60.3125, 59.5625, 58.875, 56.625, 53.5, 50.6875, 
 47.9375, 45.9375, 43.875, 40.8125, 36.0625, 31.75, 27.4375, 
 23.6875, 20.5, 17.375, 14.1875, 11.0625, 7.875, 5.875, 3.875, 
 1.875, np.nan
])
z_levels = np.array([
    0., 500., 1000., 1500., 2000., 2500., 3000., 3500., 4000., 4500.,
    5000., 5500., 6000., 6500., 7000., 7500., 8000., 8500., 9000., 9500.,
    10000., 10500., 11000., 11500., 12000., 12500., 13000., 13500., 14000., 
    14500., 15000., 15500., 16000., 16500., 17000., 17500., 18000., 18500., 
    19000., 19500., 20000.
]) / 1000  # Convert meters to kilometers

# Plot
plt.figure(figsize=(8, 6))
plt.plot(reflectivity, z_levels, label="Maximum Reflectivity")
plt.axvline(x=50, color='red', linestyle='--', label="Reflectivity = 50 dBz")

# Set axis limits and ticks
plt.xlim(0, 65)
plt.ylim(0, 20)
plt.xticks(np.arange(0, 72, 10), fontsize=26)
plt.yticks(np.arange(0, 23, 3), fontsize=26)

# Customize font sizes
plt.title("Syd Airport\nMaximum Reflectivity at Each Z-Level", fontsize=24)
plt.xlabel("Reflectivity (dBz)", fontsize=26)
plt.ylabel("Height (km)", fontsize=26)
plt.legend(fontsize=20)

# Add grid and layout adjustments
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
reflectivity = np.array([
   np.nan, 54.5, 55.8125, 61.25, 62.625, 63.0, 63.25, 62.4375, 61.5, 60.5, 59.8125, 60.125, 58.5625, 60.0, 60.125, 
    59.125, 58.25, 57.3125, 56.625, 54.0, 51.0, 47.9375, 45.4375, 44.3125, 38.4375, 30.6875, 28.875,
    27.125, 23.5, 17.625, 15.8125, 14.875, 14.0, 13.0625, 12.125, 11.1875, 10.9375, 10.875, 10.8125, 10.8125, 10.8125

])
z_levels = np.array([
    0., 500., 1000., 1500., 2000., 2500., 3000., 3500., 4000., 4500.,
    5000., 5500., 6000., 6500., 7000., 7500., 8000., 8500., 9000., 9500.,
    10000., 10500., 11000., 11500., 12000., 12500., 13000., 13500., 14000., 
    14500., 15000., 15500., 16000., 16500., 17000., 17500., 18000., 18500., 
    19000., 19500., 20000.
]) / 1000  # Convert meters to kilometers

# Plot
plt.figure(figsize=(8, 6))
plt.plot(reflectivity, z_levels, label="Maximum Reflectivity")
plt.axvline(x=50, color='red', linestyle='--', label="Reflectivity = 50 dBz")

# Set axis limits and ticks
plt.xlim(0, 65)
plt.ylim(0, 20)
plt.xticks(np.arange(0, 72, 10), fontsize=26)
plt.yticks(np.arange(0, 23, 3), fontsize=26)

# Customize font sizes
plt.title("Tamworth Airport\nMaximum Reflectivity at Each Z-Level", fontsize=24)
plt.xlabel("Reflectivity (dBz)", fontsize=26)
plt.ylabel("Height (km)", fontsize=26)
plt.legend(fontsize=20)

# Add grid and layout adjustments
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
reflectivity = np.array([
   np.nan, 56.4375, 54.4375, 58.0, 57.5625, 56.6875, 57.1875, 58.4375, 57.9375, 58.5625, 58.375, 58.9375,
    58.375, 57.9375, 58.375, 57.375, 55.8125, 54.8125, 55.125, 55.4375, 55.6875, 55.75, 53.875, 52.0, 50.125,
    48.25, 43.5, 38.125, 32.875, 27.75, 22.8125, 21.0, 20.0, 20.0625, 20.125, 20.25, 20.375, 21.0625, 22.5625, 24.0625, 21.0625

])
z_levels = np.array([
    0., 500., 1000., 1500., 2000., 2500., 3000., 3500., 4000., 4500.,
    5000., 5500., 6000., 6500., 7000., 7500., 8000., 8500., 9000., 9500.,
    10000., 10500., 11000., 11500., 12000., 12500., 13000., 13500., 14000., 
    14500., 15000., 15500., 16000., 16500., 17000., 17500., 18000., 18500., 
    19000., 19500., 20000.
]) / 1000  # Convert meters to kilometers

# Plot
plt.figure(figsize=(8, 6))
plt.plot(reflectivity, z_levels, label="Maximum Reflectivity")
plt.axvline(x=50, color='red', linestyle='--', label="Reflectivity = 50 dBz")

# Set axis limits and ticks
plt.xlim(0, 65)
plt.ylim(0, 20)
plt.xticks(np.arange(0, 72, 10), fontsize=26)
plt.yticks(np.arange(0, 23, 3), fontsize=26)

# Customize font sizes
plt.title("Richmond RAAF\nMaximum Reflectivity at Each Z-Level", fontsize=24)
plt.xlabel("Reflectivity (dBz)", fontsize=26)
plt.ylabel("Height (km)", fontsize=26)
plt.legend(fontsize=20)

# Add grid and layout adjustments
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
reflectivity = np.array([
   np.nan, 53.8125, 55.8125, 56.0625, 57.4375, 58.25, 58.1875, 58.125, 58.5, 57.5625, 56.5, 55.0625, 52.9375, 51.0625, 49.5625, 
    48.5625, 46.125, 43.875, 42.75, 42.375, 40.0, 37.0625, 34.125, 31.6875, 28.75, 25.0625, 22.4375,
    np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan


])
z_levels = np.array([
    0., 500., 1000., 1500., 2000., 2500., 3000., 3500., 4000., 4500.,
    5000., 5500., 6000., 6500., 7000., 7500., 8000., 8500., 9000., 9500.,
    10000., 10500., 11000., 11500., 12000., 12500., 13000., 13500., 14000., 
    14500., 15000., 15500., 16000., 16500., 17000., 17500., 18000., 18500., 
    19000., 19500., 20000.
]) / 1000  # Convert meters to kilometers

# Plot
plt.figure(figsize=(8, 6))
plt.plot(reflectivity, z_levels, label="Maximum Reflectivity")
plt.axvline(x=50, color='red', linestyle='--', label="Reflectivity = 50 dBz")

# Set axis limits and ticks
plt.xlim(0, 65)
plt.ylim(0, 20)
plt.xticks(np.arange(0, 72, 10), fontsize=26)
plt.yticks(np.arange(0, 23, 3), fontsize=26)

# Customize font sizes
plt.title("Moree Aero\nMaximum Reflectivity at Each Z-Level", fontsize=24)
plt.xlabel("Reflectivity (dBz)", fontsize=26)
plt.ylabel("Height (km)", fontsize=26)
plt.legend(fontsize=20)

# Add grid and layout adjustments
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
reflectivity = np.array([
  np.nan, 56.9375, 56.375, 57.75, 57.3125, 57.4375, 57.4375, 59.3125, 58.8125, 58.1875, 58.375, 58.0, 57.5625, 56.375,  
    54.4375, 52.5, 49.5625, 47.625, 46.25, 44.9375, 43.5625, 42.3125, 40.0625, 37.0, 35.8125, 35.125, 34.375,
    33.625, 32.6875, 32.4375, 32.25, 32.0, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan



])
z_levels = np.array([
    0., 500., 1000., 1500., 2000., 2500., 3000., 3500., 4000., 4500.,
    5000., 5500., 6000., 6500., 7000., 7500., 8000., 8500., 9000., 9500.,
    10000., 10500., 11000., 11500., 12000., 12500., 13000., 13500., 14000., 
    14500., 15000., 15500., 16000., 16500., 17000., 17500., 18000., 18500., 
    19000., 19500., 20000.
]) / 1000  # Convert meters to kilometers

# Plot
plt.figure(figsize=(8, 6))
plt.plot(reflectivity, z_levels, label="Maximum Reflectivity")
plt.axvline(x=50, color='red', linestyle='--', label="Reflectivity = 50 dBz")

# Set axis limits and ticks
plt.xlim(0, 65)
plt.ylim(0, 20)
plt.xticks(np.arange(0, 72, 10), fontsize=26)
plt.yticks(np.arange(0, 23, 3), fontsize=26)

# Customize font sizes
plt.title("Wagga Wagga\nMaximum Reflectivity at Each Z-Level", fontsize=24)
plt.xlabel("Reflectivity (dBz)", fontsize=26)
plt.ylabel("Height (km)", fontsize=26)
plt.legend(fontsize=20, loc = 'lower left')

# Add grid and layout adjustments
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
